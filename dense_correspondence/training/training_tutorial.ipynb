# %%
import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()
from dense_correspondence.training.training import *
import sys
import logging

# utils.set_default_cuda_visible_devices()
utils.set_cuda_visible_devices([1, 2, 3, 4, 5, 6, 7]) # use this to manually set CUDA_VISIBLE_DEVICES

from dense_correspondence.training.training import DenseCorrespondenceTraining
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
logging.basicConfig(level=logging.INFO)
# Out:
# setting CUDA_VISIBLE_DEVICES =  1,2,3,4,5,6,7,

# %% [markdown]
# ## Load the configuration for training

# %%
config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'dataset', 'composite', 'rope_902_mixed_slightvar_depth_only.yaml')
config = utils.getDictFromYamlFilename(config_filename)

train_config_file = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'training', 'training.yaml')

train_config = utils.getDictFromYamlFilename(train_config_file)
dataset = SpartanDataset(config=config)

logging_dir = "code/data_volume/pdc_synthetic_2/trained_models/tutorials"
num_iterations = 3500
d = 3 # the descriptor dimension
normalize = True
name = "rope_902_mixed_sphere_slightvar_depth_norm_%d" %(d)
train_config["training"]["logging_dir_name"] = name
train_config["training"]["logging_dir"] = logging_dir
train_config["dense_correspondence_network"]["descriptor_dimension"] = d
train_config["dense_correspondence_network"]["normalize"] = normalize
train_config["training"]["num_iterations"] = num_iterations

TRAIN = True
EVALUATE = True
# Out:
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     3600

# %% [markdown]
# ## TRAIN

# %%
# All of the saved data for this network will be located in the
# code/data_volume/pdc/trained_models/tutorials/caterpillar_3 folder

if TRAIN:
    print "training descriptor of dimension %d" %(d)
    train = DenseCorrespondenceTraining(dataset=dataset, config=train_config)
    train.run()
    print "finished training descriptor of dimension %d" %(d)
# Out:
# training descriptor of dimension 3
# using SINGLE_OBJECT_WITHIN_SCENE
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Sampling indices in range 360
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:2622: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# Same scene, same object
# iteration 1 took 0.242 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 2 took 0.157 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3 took 0.229 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 4 took 0.247 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 5 took 0.189 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 6 took 0.152 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 7 took 0.295 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 8 took 0.273 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 9 took 0.202 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 10 took 0.139 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 11 took 0.232 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 12 took 0.293 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 13 took 0.155 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 14 took 0.163 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 15 took 0.293 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 16 took 0.210 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 17 took 0.301 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 18 took 0.257 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 19 took 0.216 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3358 took 0.290 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3359 took 0.288 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3360 took 0.129 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3361 took 0.137 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3362 took 0.288 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3363 took 0.199 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3364 took 0.230 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3365 took 0.273 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3366 took 0.149 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3367 took 0.131 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3368 took 0.210 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3369 took 0.242 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3370 took 0.190 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3371 took 0.153 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3372 took 0.149 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3373 took 0.129 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3374 took 0.168 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3375 took 0.152 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3376 took 0.197 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3377 took 0.274 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3378 took 0.203 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3379 took 0.168 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3380 took 0.150 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3381 took 0.284 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3382 took 0.154 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3383 took 0.221 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3384 took 0.206 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3385 took 0.292 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3386 took 0.292 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3387 took 0.272 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3388 took 0.196 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3389 took 0.290 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3390 took 0.249 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3391 took 0.217 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3392 took 0.289 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3393 took 0.152 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3394 took 0.295 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3395 took 0.150 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3396 took 0.212 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# iteration 3397 took 0.291 seconds
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3398 took 0.229 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3399 took 0.193 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3400 took 0.168 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3401 took 0.291 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3402 took 0.238 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3403 took 0.199 seconds
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3404 took 0.282 seconds
# Same scene, same object

# %% [markdown]
# ## EVAL

# %%
model_folder = os.path.join(logging_dir, name)
model_folder = utils.convert_to_absolute_path(model_folder)

if True: #EVALUATE
    DCE = DenseCorrespondenceEvaluation
    num_image_pairs = 100
    DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs)
# Out:
# got /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_902_mixed_sphere_slightvar_depth_norm_3
# got output_dir
# got train_output_dir /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_902_mixed_sphere_slightvar_depth_norm_3/analysis/train
# got test_output_dir /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_902_mixed_sphere_slightvar_depth_norm_3/analysis/test
# got cross_scene_output_dir /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_902_mixed_sphere_slightvar_depth_norm_3/analysis/cross_scene
# making necessary dirs
# model_param_file 003501.pth
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     3600
# computing stats
# doing dcn eval
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:2622: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# done computing stats
# computing statistics for image 0 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 5 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 10 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 15 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 20 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 25 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 30 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 35 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 40 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 45 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 50 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 55 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 60 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 65 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 70 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 75 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 80 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 85 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 90 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 95 of 100, scene_name rope_902_mixed_slightvar_depth
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 0 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 5 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 10 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 15 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 20 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 25 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 30 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 35 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 40 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 45 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 50 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 55 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 60 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 65 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 70 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 75 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 80 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 85 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 90 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 95 of 100, scene_name rope_902_mixed_slightvar_depth_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm

# %% [markdown]
# See `evaluation_quantitative_tutorial.ipynb` for a better place to display the plots.
