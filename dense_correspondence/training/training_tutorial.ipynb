# %%
import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()
from dense_correspondence.training.training import *
import sys
import logging

#utils.set_default_cuda_visible_devices()
utils.set_cuda_visible_devices([0, 1, 2, 3, 4, 5, 6, 7]) # use this to manually set CUDA_VISIBLE_DEVICES

from dense_correspondence.training.training import DenseCorrespondenceTraining
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
logging.basicConfig(level=logging.INFO)

from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
# Out:
# setting CUDA_VISIBLE_DEVICES =  0,1,2,3,4,5,6,7,

# %% [markdown]
# ## Load the configuration for training

# %%
config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'dataset', 'composite', 'rope_rigid_only.yaml')
config = utils.getDictFromYamlFilename(config_filename)

train_config_file = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'training', 'training.yaml')

train_config = utils.getDictFromYamlFilename(train_config_file)
dataset = SpartanDataset(config=config)

logging_dir = "code/data_volume/pdc_synthetic_2/trained_models/tutorials"
num_iterations = 3500
d = 3# the descriptor dimension
normalize=True
name = "rope_rigid_norm_%d" %(d)
train_config["training"]["logging_dir_name"] = name
train_config["dense_correspondence_network"]["normalize"] = normalize
train_config["training"]["logging_dir"] = logging_dir
train_config["dense_correspondence_network"]["descriptor_dimension"] = d
train_config["training"]["num_iterations"] = num_iterations

TRAIN = True
EVALUATE = True
# Out:
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     3730

# %% [markdown]
# ## Train the network
#
# This should take about ~12-15 minutes with a GTX 1080 Ti

# %%
# All of the saved data for this network will be located in the
# code/data_volume/pdc/trained_models/tutorials/caterpillar_3 folder

if TRAIN:
    print "training descriptor of dimension %d" %(d)
    train = DenseCorrespondenceTraining(dataset=dataset, config=train_config)
    train.run()
    print "finished training descriptor of dimension %d" %(d)
# Out:
# INFO:root:Loading pose data for scene rope_rigid
# training descriptor of dimension 16
# INFO:root:enabling domain randomization
# using SINGLE_OBJECT_WITHIN_SCENE
# INFO:root:setting up tensorboard_logger
# INFO:root:tensorboard logger started
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.159 seconds
# logging train loss tensor(0.5268, device='cuda:0')
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.134 seconds
# logging train loss tensor(0.2753, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.3371, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1467, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1857, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1135, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1255, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# logging train loss tensor(0.1256, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.1187, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 10 of 3500
# INFO:root:single iteration took 0.130 seconds
# INFO:root:Training is 0 percent complete
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1258, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# logging train loss tensor(0.1071, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1192, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1074, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.1124, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1098, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.1053, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.0998, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1112, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1203, device='cuda:0')
# Same scene, same object
# INFO:root:Training on iteration 20 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 0 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# logging train loss tensor(0.1356, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1182, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.1110, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1230, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1029, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.0902, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.0910, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.131 seconds
# logging train loss tensor(0.0952, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1122, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.0955, device='cuda:0')
# INFO:root:Training on iteration 30 of 3500
# INFO:root:single iteration took 0.129 seconds
# INFO:root:Training is 0 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1062, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.0838, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1316, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1082, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.0921, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.0868, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1122, device='cuda:0')
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.1078, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1143, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1831, device='cuda:0')
# INFO:root:Training on iteration 40 of 3500
# INFO:root:single iteration took 0.129 seconds
# INFO:root:Training is 1 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1172, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1076, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1319, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1535, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1955, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1055, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1084, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.1054, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1146, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1057, device='cuda:0')
# normalizing descriptor norm
# INFO:root:Training on iteration 50 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 1 percent complete
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1022, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1069, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1070, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1346, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1108, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.131 seconds
# logging train loss tensor(0.1213, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0899, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.1252, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1013, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0953, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 60 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 1 percent complete
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1200, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1221, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1761, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.1075, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1100, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1361, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1276, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.0834, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.0946, device='cuda:0')
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1542, device='cuda:0')
# INFO:root:Training on iteration 70 of 3500
# INFO:root:single iteration took 0.127 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1068, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1445, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1272, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1052, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1124, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0904, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.2478, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1251, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1378, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# Same scene, same object
# logging train loss tensor(0.1016, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 80 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1325, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1246, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1133, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1459, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1301, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1206, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.1117, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.1266, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.1199, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.1032, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# INFO:root:Training on iteration 90 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# logging train loss tensor(0.1030, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.1027, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# Same scene, same object
# logging train loss tensor(0.1168, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.1104, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.0990, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.0999, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1088, device='cuda:0')
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.0917, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.0999, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1004, device='cuda:0')
# INFO:root:Training on iteration 100 of 3500
# INFO:root:single iteration took 0.130 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.1093, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.0925, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1805, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.2532, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.1425, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1090, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.0912, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.0988, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.0842, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.0876, device='cuda:0')
# normalizing descriptor norm
# INFO:root:Training on iteration 110 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 3 percent complete
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1392, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1335, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1148, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0843, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1233, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.0844, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0928, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0897, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0997, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.1123, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 120 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 3 percent complete
# Same scene, same object
# single iteration took 0.126 seconds
# logging train loss tensor(0.1195, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.0959, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# logging train loss tensor(0.1248, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1293, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.131 seconds
# logging train loss tensor(0.1216, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0873, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1091, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# logging train loss tensor(0.0924, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.1012, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1478, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 130 of 3500
# INFO:root:single iteration took 0.127 seconds
# INFO:root:Training is 3 percent complete
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1096, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1143, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1315, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1029, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.131 seconds
# logging train loss tensor(0.1063, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0845, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.1467, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.0813, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.132 seconds
# Same scene, same object
# logging train loss tensor(0.1002, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.1520, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# INFO:root:Training on iteration 140 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# logging train loss tensor(0.2351, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.1268, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.0969, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1724, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# logging train loss tensor(0.0813, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.1044, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# logging train loss tensor(0.0983, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.0900, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# logging train loss tensor(0.1016, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1061, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 150 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1158, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# logging train loss tensor(0.0967, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0732, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.1118, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0985, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0846, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0953, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# logging train loss tensor(0.1129, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.0890, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.0924, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# INFO:root:Training on iteration 160 of 3500
# INFO:root:single iteration took 0.129 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# logging train loss tensor(0.1347, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1322, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.2674, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.0868, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.2142, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.1025, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss Same scene, same object
# tensor(0.0967, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.1199, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.1184, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# Same scene, same object
# logging train loss tensor(0.1042, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# INFO:root:Training on iteration 170 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# logging train loss tensor(0.1129, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.1066, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1076, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1452, device='cuda:0')
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1047, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.0891, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1017, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.0765, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.0857, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1672, device='cuda:0')
# INFO:root:Training on iteration 180 of 3500
# INFO:root:single iteration took 0.131 seconds
# INFO:root:Training is 5 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.131 seconds
# logging train loss tensor(0.0936, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.0726, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1297, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.0948, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1402, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1059, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0833, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1190, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1014, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss Same scene, same object
# INFO:root:Training on iteration 190 of 3500
# tensor(0.1033, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1554, device='cuda:0')
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 5 percent complete
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1185, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1977, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1442, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.1433, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.131 seconds
# logging train loss tensor(0.1019, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1205, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.1002, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1264, device='cuda:0')
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.0887, device='cuda:0')
# INFO:root:Training on iteration 200 of 3500
# INFO:root:single iteration took 0.129 seconds
# INFO:root:Training is 5 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.0915, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.0814, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.0808, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.130 seconds
# logging train loss tensor(0.1007, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1032, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1191, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.0822, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss Same scene, same object
# tensor(0.0999, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# logging train loss tensor(0.1209, device='cuda:0')
# Same scene, same object
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.0896, device='cuda:0')
# INFO:root:Training on iteration 210 of 3500
# INFO:root:single iteration took 0.127 seconds
# INFO:root:Training is 6 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# logging train loss tensor(0.1115, device='cuda:0')
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.0720, device='cuda:0')
# normalizing descriptor norm
# Same scene, same object
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# logging train loss tensor(0.1308, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0850, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.0933, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.0817, device='cuda:0')
# normalizing descriptor norm
# ...
# INFO:root:single iteration took 0.127 seconds
# INFO:root:Training is 98 percent complete
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0730, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.1251, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.131 seconds
# logging train loss tensor(0.0853, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1028, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.0685, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1646, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0897, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0723, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0730, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.0681, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3440 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 98 percent complete
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0625, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.133 seconds
# logging train loss tensor(0.0988, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0760, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0834, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0765, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# logging train loss tensor(0.0730, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# logging train loss tensor(0.0848, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0668, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0770, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0760, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3450 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 98 percent complete
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0920, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0771, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0833, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.0787, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.1057, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.0968, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0881, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1058, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0834, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0863, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3460 of 3500
# INFO:root:single iteration took 0.129 seconds
# INFO:root:Training is 98 percent complete
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0784, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0968, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.131 seconds
# logging train loss tensor(0.1038, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.131 seconds
# logging train loss tensor(0.0871, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.0944, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.130 seconds
# logging train loss tensor(0.1162, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0731, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.0772, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0890, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0745, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3470 of 3500
# INFO:root:single iteration took 0.132 seconds
# INFO:root:Training is 99 percent complete
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.0806, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1062, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0847, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0903, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0793, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0737, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0779, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# logging train loss tensor(0., device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1302, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0784, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3480 of 3500
# INFO:root:single iteration took 0.129 seconds
# INFO:root:Training is 99 percent complete
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0763, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.1288, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.1137, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1211, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0884, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0784, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0989, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0719, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1169, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0890, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3490 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 99 percent complete
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0859, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0812, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.129 seconds
# logging train loss tensor(0.0829, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1099, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.132 seconds
# logging train loss tensor(0.0733, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.127 seconds
# logging train loss tensor(0.0920, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1004, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.1100, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# Same scene, same object
# logging train loss tensor(0.1072, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# logging train loss tensor(0.0829, device='cuda:0')
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# logging train loss tensor(0.0957, device='cuda:0')
# INFO:root:Training on iteration 3500 of 3500
# INFO:root:single iteration took 0.128 seconds
# INFO:root:Training is 100 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.145 seconds
# logging train loss tensor(0.1053, device='cuda:0')
# INFO:root:Finished testing after 3500 iterations
# finished training descriptor of dimension 16

# %% [markdown]
# ## Evaluate the network quantitatively
#
# This should take ~5 minutes.

# %%
model_folder = os.path.join(logging_dir, name)
model_folder = utils.convert_to_absolute_path(model_folder)

if EVALUATE:
    DCE = DenseCorrespondenceEvaluation
    num_image_pairs = 100
    DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs, dataset=dataset, cross_scene=False)
# Out:
# model_param_file 003501.pth
# INFO:root:Computing descriptor statistics on dataset
# INFO:root:Loading pose data for scene rope_rigid
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# INFO:root:Evaluating network on train data
# computing statistics for image 0 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 5 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 10 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 15 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 20 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 25 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 30 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 35 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 40 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 45 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 50 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 55 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 60 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 65 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 70 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 75 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 80 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 85 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 90 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 95 of 100, scene_name rope_rigid
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# INFO:root:Evaluating network on test data
# INFO:root:Loading pose data for scene rope_rigid_test
# computing statistics for image 0 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 5 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 10 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 15 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 20 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 25 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 30 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 35 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 40 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 45 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 50 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 55 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 60 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 65 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 70 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 75 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 80 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 85 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 90 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 95 of 100, scene_name rope_rigid_test
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# INFO:root:Making plots
# INFO:root:0     77.897368
# 0      7.211103
# 0    152.069063
# 0     39.698866
# 0      6.403124
# 0     29.206164
# 0     14.142136
# 0    249.633732
# 0     18.973666
# 0     21.540659
# 0     43.324358
# 0     30.083218
# 0     26.076810
# 0     24.000000
# 0     43.680659
# 0     14.866069
# 0     40.360872
# 0     40.311289
# 0     19.104973
# 0     83.198558
# 0      3.605551
# 0     87.200917
# 0     11.045361
# 0      7.211103
# 0     54.626001
# 0     40.224371
# 0     37.589892
# 0     40.024992
# 0     35.693137
# 0     38.832976
#         ...
# 0    130.299655
# 0     14.866069
# 0    100.124922
# 0     38.288379
# 0      4.472136
# 0    256.725534
# 0     18.788294
# 0     27.166155
# 0     33.421550
# 0     45.541190
# 0     14.866069
# 0     23.769729
# 0     21.213203
# 0     20.099751
# 0     30.083218
# 0     24.186773
# 0     20.615528
# 0      6.082763
# 0     35.468296
# 0     64.140471
# 0     94.148818
# 0    217.082933
# 0    112.294256
# 0      8.246211
# 0     15.132746
# 0     20.396078
# 0     24.351591
# 0     97.082439
# 0     16.155494
# 0     15.652476
# Name: pixel_match_error_l2, Length: 424, dtype: float64
# INFO:root:0     77.897368
# 0      7.211103
# 0    152.069063
# 0     39.698866
# 0      6.403124
# 0     29.206164
# 0     14.142136
# 0    249.633732
# 0     18.973666
# 0     21.540659
# 0     15.033296
# 0     30.083218
# 0     26.076810
# 0     24.000000
# 0     10.049876
# 0     19.235384
# 0     12.529964
# 0     35.355339
# 0     11.180340
# 0     52.038447
# 0      2.000000
# 0     87.200917
# 0     11.045361
# 0     16.031220
# 0     54.626001
# 0      7.071068
# 0      4.472136
# 0      5.000000
# 0      1.000000
# 0      6.403124
#         ...
# 0    130.299655
# 0     14.866069
# 0    100.124922
# 0      8.944272
# 0      4.472136
# 0     13.152946
# 0     18.788294
# 0     27.166155
# 0     31.064449
# 0     45.541190
# 0      8.544004
# 0     16.492423
# 0      9.219544
# 0      9.433981
# 0      3.162278
# 0      5.000000
# 0      6.082763
# 0     11.045361
# 0     34.409301
# 0     55.569776
# 0     74.431176
# 0    217.082933
# 0     54.203321
# 0      8.246211
# 0     15.132746
# 0     20.396078
# 0     23.409400
# 0    105.574618
# 0     24.000000
# 0     14.560220
# Name: pixel_match_error_l2_masked, Length: 424, dtype: float64
# INFO:root:0     43.863424
# 0     28.425341
# 0     41.725292
# 0     59.076222
# 0     49.648766
# 0     17.000000
# 0     35.468296
# 0    141.777995
# 0    127.314571
# 0     10.049876
# 0     15.000000
# 0     26.248809
# 0     24.083189
# 0     99.859902
# 0     27.202941
# 0      7.615773
# 0     13.000000
# 0     42.720019
# 0     29.832868
# 0     92.282176
# 0     88.684835
# 0     29.120440
# 0     33.241540
# 0     15.811388
# 0     59.908263
# 0     41.146081
# 0    129.356098
# 0     15.524175
# 0     33.136083
# 0     14.866069
#         ...
# 0    288.916943
# 0    213.974298
# 0     18.027756
# 0     35.846897
# 0     28.653098
# 0     36.221541
# 0     43.046487
# 0     33.241540
# 0     23.323808
# 0     28.442925
# 0     70.092796
# 0     31.144823
# 0     29.529646
# 0     62.369865
# 0     31.016125
# 0    252.160663
# 0      4.472136
# 0     20.223748
# 0     10.198039
# 0     15.556349
# 0    118.067777
# 0     44.643029
# 0     45.177428
# 0     17.088007
# 0     40.199502
# 0     27.658633
# 0     85.375641
# 0      7.615773
# 0     91.525953
# 0     38.013156
# Name: pixel_match_error_l2, Length: 494, dtype: float64
# INFO:root:0      5.000000
# 0      8.062258
# 0      4.123106
# 0     37.643060
# 0     26.172505
# 0     11.000000
# 0      7.280110
# 0    114.856432
# 0    103.237590
# 0      6.082763
# 0     14.764823
# 0      9.848858
# 0     17.720045
# 0     99.859902
# 0     10.000000
# 0      4.000000
# 0     15.811388
# 0     28.792360
# 0     12.041595
# 0     92.282176
# 0     89.470666
# 0     18.601075
# 0     32.756679
# 0     15.811388
# 0     59.908263
# 0     16.552945
# 0    130.782262
# 0    106.512910
# 0     33.136083
# 0     14.866069
#         ...
# 0      7.810250
# 0     66.640828
# 0     18.027756
# 0     22.360680
# 0     41.725292
# 0     28.425341
# 0      7.000000
# 0     52.392748
# 0     19.416488
# 0     24.186773
# 0     19.104973
# 0     63.976558
# 0     26.076810
# 0     40.049969
# 0     29.427878
# 0    252.160663
# 0      4.472136
# 0     10.000000
# 0     10.198039
# 0      2.828427
# 0     99.639350
# 0     29.966648
# 0     31.906112
# 0     17.088007
# 0     40.199502
# 0     27.658633
# 0     82.219219
# 0      7.615773
# 0     50.447993
# 0      1.414214
# Name: pixel_match_error_l2_masked, Length: 494, dtype: float64
# INFO:root:Finished running evaluation on network

# %% [markdown]
# See `evaluation_quantitative_tutorial.ipynb` for a better place to display the plots.
