# %%
import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()
from dense_correspondence.training.training import *
import sys
import logging

#utils.set_default_cuda_visible_devices()
utils.set_cuda_visible_devices([0, 1, 2, 3, 4, 5, 6, 7]) # use this to manually set CUDA_VISIBLE_DEVICES

from dense_correspondence.training.training import DenseCorrespondenceTraining
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
logging.basicConfig(level=logging.INFO)

from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
# Out:
# setting CUDA_VISIBLE_DEVICES =  0,1,2,3,4,5,6,7,

# %% [markdown]
# ## Load the configuration for training

# %%
config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'dataset', 'composite', 'wolf_banana_pipe.yaml')
config = utils.getDictFromYamlFilename(config_filename)

train_config_file = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'training', 'training.yaml')

train_config = utils.getDictFromYamlFilename(train_config_file)
dataset = SpartanDataset(config=config)

logging_dir = "code/data_volume/pdc_synthetic/trained_models/tutorials"
num_iterations = 3500
d = 3 # the descriptor dimension
name = "wolf_banana_pipe_%d" %(d)
train_config["training"]["logging_dir_name"] = name
train_config["training"]["logging_dir"] = logging_dir
train_config["dense_correspondence_network"]["descriptor_dimension"] = d
train_config["training"]["num_iterations"] = num_iterations

TRAIN = True
EVALUATE = True
# Out:
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 3
#    - total images:     11190

# %% [markdown]
# ## Train the network
#
# This should take about ~12-15 minutes with a GTX 1080 Ti

# %%
# All of the saved data for this network will be located in the
# code/data_volume/pdc/trained_models/tutorials/caterpillar_3 folder

if TRAIN:
    print "training descriptor of dimension %d" %(d)
    train = DenseCorrespondenceTraining(dataset=dataset, config=train_config)
    train.run()
    print "finished training descriptor of dimension %d" %(d)
# Out:
# INFO:root:Loading pose data for scene pipe
# training descriptor of dimension 3
# INFO:root:Loading pose data for scene wolf
# INFO:root:Loading pose data for scene banana
# INFO:root:enabling domain randomization
# INFO:root:setting up tensorboard_logger
# INFO:root:tensorboard logger started
# using SINGLE_OBJECT_WITHIN_SCENE
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:2622: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.166 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.131 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 10 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 0 percent complete
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# INFO:root:Training on iteration 20 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 0 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 30 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 0 percent complete
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 40 of 3500
# INFO:root:single iteration took 0.122 seconds
# INFO:root:Training is 1 percent complete
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 50 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 1 percent complete
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 60 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 1 percent complete
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 70 of 3500
# INFO:root:single iteration took 0.122 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# INFO:root:Training on iteration 80 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 90 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 100 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 2 percent complete
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 110 of 3500
# INFO:root:single iteration took 0.121 seconds
# INFO:root:Training is 3 percent complete
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.121 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 120 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 3 percent complete
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# INFO:root:Training on iteration 130 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 3 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# INFO:root:Training on iteration 140 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 150 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 160 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 170 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 4 percent complete
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.121 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 180 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 5 percent complete
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 190 of 3500
# INFO:root:single iteration took 0.122 seconds
# INFO:root:Training is 5 percent complete
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 200 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 5 percent complete
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# INFO:root:Training on iteration 210 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 6 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 220 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 6 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# INFO:root:Training on iteration 230 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 6 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 240 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 6 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# INFO:root:Training on iteration 250 of 3500
# INFO:root:single iteration took 0.122 seconds
# INFO:root:Training is 7 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# INFO:root:Training on iteration 260 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 7 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 270 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 7 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 280 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 8 percent complete
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 290 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 8 percent complete
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 300 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 8 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 310 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 8 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 320 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 9 percent complete
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 330 of 3500
# INFO:root:single iteration took 0.122 seconds
# INFO:root:Training is 9 percent complete
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 340 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 9 percent complete
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 350 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 10 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 360 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 10 percent complete
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.128 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 370 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 10 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 380 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 10 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 390 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 11 percent complete
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# INFO:root:Training on iteration 400 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 11 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 410 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 11 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# ...
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3370 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 96 percent complete
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 3380 of 3500
# INFO:root:single iteration took 0.127 seconds
# INFO:root:Training is 96 percent complete
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# INFO:root:Training on iteration 3390 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 96 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3400 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 97 percent complete
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3410 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 97 percent complete
# Same scene, same object
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3420 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 97 percent complete
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.128 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3430 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 98 percent complete
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 3440 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 98 percent complete
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# INFO:root:Training on iteration 3450 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 98 percent complete
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 3460 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 98 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.122 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 3470 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 99 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# INFO:root:Training on iteration 3480 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 99 percent complete
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# INFO:root:Training on iteration 3490 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 99 percent complete
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# Same scene, same object
# single iteration took 0.123 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# INFO:root:Training on iteration 3500 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 100 percent complete
# Same scene, same object
# INFO:root:Finished testing after 3500 iterations
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# finished training descriptor of dimension 3

# %% [markdown]
# ## Evaluate the network quantitatively
#
# This should take ~5 minutes.

# %%
model_folder = os.path.join(logging_dir, name)
model_folder = utils.convert_to_absolute_path(model_folder)

if EVALUATE:
    DCE = DenseCorrespondenceEvaluation
    num_image_pairs = 100
    DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs, dataset=dataset, cross_scene=False)
# Out:
# model_param_file 003501.pth
# INFO:root:Computing descriptor statistics on dataset
# INFO:root:Evaluating network on train data
# computing statistics for image 0 of 100, scene_name banana
# scene
# computing statistics for image 5 of 100, scene_name banana
# scene
# computing statistics for image 10 of 100, scene_name pipe
# scene
# computing statistics for image 15 of 100, scene_name banana
# scene
# computing statistics for image 20 of 100, scene_name pipe
# scene
# computing statistics for image 25 of 100, scene_name pipe
# scene
# computing statistics for image 30 of 100, scene_name pipe
# scene
# computing statistics for image 35 of 100, scene_name pipe
# scene
# computing statistics for image 40 of 100, scene_name wolf
# scene
# computing statistics for image 45 of 100, scene_name banana
# scene
# computing statistics for image 50 of 100, scene_name wolf
# scene
# computing statistics for image 55 of 100, scene_name banana
# scene
# computing statistics for image 60 of 100, scene_name banana
# scene
# computing statistics for image 65 of 100, scene_name pipe
# scene
# computing statistics for image 70 of 100, scene_name banana
# scene
# computing statistics for image 75 of 100, scene_name banana
# scene
# computing statistics for image 80 of 100, scene_name banana
# scene
# computing statistics for image 85 of 100, scene_name pipe
# scene
# computing statistics for image 90 of 100, scene_name wolf
# scene
# computing statistics for image 95 of 100, scene_name banana
# scene
# INFO:root:Evaluating network on test data
# INFO:root:Loading pose data for scene banana_test
# computing statistics for image 0 of 100, scene_name banana_test
# scene
# INFO:root:Loading pose data for scene pipe_test
# INFO:root:Loading pose data for scene wolf_test
# computing statistics for image 5 of 100, scene_name banana_test
# scene
# computing statistics for image 10 of 100, scene_name pipe_test
# scene
# computing statistics for image 15 of 100, scene_name wolf_test
# scene
# computing statistics for image 20 of 100, scene_name banana_test
# scene
# computing statistics for image 25 of 100, scene_name pipe_test
# scene
# computing statistics for image 30 of 100, scene_name pipe_test
# scene
# computing statistics for image 35 of 100, scene_name wolf_test
# scene
# computing statistics for image 40 of 100, scene_name wolf_test
# scene
# computing statistics for image 45 of 100, scene_name pipe_test
# scene
# computing statistics for image 50 of 100, scene_name wolf_test
# scene
# computing statistics for image 55 of 100, scene_name pipe_test
# scene
# computing statistics for image 60 of 100, scene_name wolf_test
# scene
# computing statistics for image 65 of 100, scene_name banana_test
# scene
# computing statistics for image 70 of 100, scene_name banana_test
# scene
# computing statistics for image 75 of 100, scene_name wolf_test
# scene
# computing statistics for image 80 of 100, scene_name banana_test
# scene
# computing statistics for image 85 of 100, scene_name pipe_test
# scene
# computing statistics for image 90 of 100, scene_name banana_test
# scene
# computing statistics for image 95 of 100, scene_name pipe_test
# scene
# INFO:root:Making plots
# INFO:root:0     38.078866
# 0     12.529964
# 0     23.537205
# 0     11.180340
# 0     15.132746
# 0     35.128336
# 0     29.154759
# 0     13.416408
# 0     33.376639
# 0     31.048349
# 0     35.355339
# 0     14.422205
# 0     11.045361
# 0     11.704700
# 0     11.401754
# 0     72.801099
# 0     14.866069
# 0    111.516815
# 0    137.360839
# 0     13.000000
# 0     11.661904
# 0     94.762862
# 0     20.396078
# 0     23.086793
# 0     46.043458
# 0     37.536649
# 0     58.008620
# 0     36.796739
# 0     31.953091
# 0     76.941536
#         ...
# 0     19.000000
# 0     18.357560
# 0    241.107860
# 0      8.062258
# 0     35.227830
# 0     17.492856
# 0      2.236068
# 0      9.848858
# 0     38.209946
# 0      5.385165
# 0      8.944272
# 0      5.000000
# 0     15.524175
# 0     31.144823
# 0    139.262342
# 0     68.007353
# 0    101.769347
# 0     24.351591
# 0     47.759816
# 0     43.382024
# 0    107.377838
# 0     48.662100
# 0     48.826222
# 0     29.410882
# 0     16.643317
# 0     35.000000
# 0    121.198185
# 0      3.000000
# 0     29.154759
# 0    110.308658
# Name: pixel_match_error_l2, Length: 529, dtype: float64
# INFO:root:0     38.078866
# 0     12.529964
# 0     23.537205
# 0     11.180340
# 0     19.849433
# 0     31.144823
# 0     19.416488
# 0     13.416408
# 0     31.144823
# 0     13.152946
# 0     21.023796
# 0     14.422205
# 0     11.045361
# 0     28.442925
# 0     11.401754
# 0     72.346389
# 0     11.661904
# 0    135.882302
# 0    142.863571
# 0      7.211103
# 0      3.000000
# 0     94.047860
# 0     20.396078
# 0     23.086793
# 0     46.043458
# 0     37.536649
# 0     58.008620
# 0     45.793013
# 0     31.953091
# 0     76.941536
#         ...
# 0     15.297059
# 0     18.357560
# 0    239.776980
# 0      8.062258
# 0     35.227830
# 0     17.492856
# 0      2.236068
# 0      9.848858
# 0     38.209946
# 0      5.385165
# 0      8.944272
# 0      5.000000
# 0     15.524175
# 0     14.422205
# 0    139.262342
# 0     68.007353
# 0    101.769347
# 0     24.351591
# 0     48.383882
# 0     43.382024
# 0    107.377838
# 0     48.662100
# 0     48.826222
# 0     29.410882
# 0     18.384776
# 0    122.429572
# 0    124.919974
# 0      3.000000
# 0     27.294688
# 0    118.456743
# Name: pixel_match_error_l2_masked, Length: 529, dtype: float64
# INFO:root:0     29.017236
# 0     75.239617
# 0     45.099889
# 0    125.538839
# 0     80.262071
# 0     11.401754
# 0    110.059075
# 0      8.602325
# 0     82.152298
# 0    100.439036
# 0    122.196563
# 0    116.297033
# 0     24.413111
# 0     88.887569
# 0     63.600314
# 0     93.493315
# 0     25.298221
# 0     22.671568
# 0    132.034087
# 0     31.622777
# 0    105.475116
# 0     31.906112
# 0     22.803509
# 0     83.600239
# 0     39.962482
# 0     37.202150
# 0     24.207437
# 0     49.040799
# 0     55.865911
# 0     41.773197
#         ...
# 0     39.115214
# 0     14.317821
# 0     29.017236
# 0     39.051248
# 0    195.064092
# 0     59.933296
# 0     56.000000
# 0      9.433981
# 0      6.403124
# 0     56.938563
# 0     60.166436
# 0     17.720045
# 0     33.955854
# 0     41.048752
# 0     32.015621
# 0     53.235327
# 0     51.312766
# 0     49.819675
# 0     46.647615
# 0     14.212670
# 0     41.012193
# 0     16.970563
# 0    128.413395
# 0    160.112460
# 0     36.496575
# 0     26.076810
# 0    111.157546
# 0     82.024387
# 0    199.969998
# 0    101.493842
# Name: pixel_match_error_l2, Length: 406, dtype: float64
# INFO:root:0     28.635642
# 0     75.239617
# 0     45.099889
# 0    120.830460
# 0     80.262071
# 0     11.401754
# 0     97.637083
# 0      8.602325
# 0     82.152298
# 0    111.664677
# 0    122.196563
# 0    115.831775
# 0     24.413111
# 0     84.291162
# 0     13.152946
# 0     93.493315
# 0     25.298221
# 0     22.671568
# 0    135.440024
# 0     31.622777
# 0    105.475116
# 0     31.906112
# 0     22.803509
# 0     83.600239
# 0     39.962482
# 0     37.202150
# 0     24.207437
# 0     49.040799
# 0     56.568542
# 0     41.773197
#         ...
# 0     39.115214
# 0     14.317821
# 0     29.017236
# 0     39.051248
# 0    196.603662
# 0     68.883960
# 0     27.730849
# 0      9.433981
# 0      6.403124
# 0     54.037024
# 0     25.495098
# 0     17.720045
# 0     56.142675
# 0     54.037024
# 0     21.000000
# 0     15.000000
# 0     22.090722
# 0     27.658633
# 0     11.000000
# 0     12.206556
# 0     41.012193
# 0     16.970563
# 0    128.413395
# 0     39.395431
# 0     36.496575
# 0     26.076810
# 0    108.558740
# 0     82.024387
# 0     27.294688
# 0    101.493842
# Name: pixel_match_error_l2_masked, Length: 406, dtype: float64
# INFO:root:Evaluating network on across object data
# INFO:root:0    0.016590
# 0    0.006135
# 0    0.027386
# 0    0.006925
# 0    0.009276
# 0    0.017276
# 0    0.001583
# 0    0.006149
# 0    0.025416
# 0    0.004597
# 0    0.005526
# 0    0.014484
# 0    0.003945
# 0    0.007859
# 0    0.006484
# 0    0.019547
# 0    0.005792
# 0    0.000314
# 0    0.006281
# 0    0.015533
# 0    0.007433
# 0    0.017097
# 0    0.002702
# 0    0.004579
# 0    0.002216
# 0    0.004311
# 0    0.004287
# 0    0.012066
# 0    0.007797
# 0    0.015936
#        ...
# 0    0.005658
# 0    0.023348
# 0    0.060518
# 0    0.001966
# 0    0.007552
# 0    0.004022
# 0    0.003198
# 0    0.053678
# 0    0.001316
# 0    0.039127
# 0    0.034175
# 0    0.122515
# 0    0.087943
# 0    0.001076
# 0    0.003627
# 0    0.007747
# 0    0.005535
# 0    0.005729
# 0    0.080586
# 0    0.003873
# 0    0.005745
# 0    0.034611
# 0    0.003252
# 0    0.009669
# 0    0.002659
# 0    0.002203
# 0    0.005696
# 0    0.002481
# 0    0.001903
# 0    0.012317
# Name: norm_diff_descriptor_best_match, Length: 2500, dtype: float64
# INFO:root:Finished running evaluation on network

# %% [markdown]
# See `evaluation_quantitative_tutorial.ipynb` for a better place to display the plots.
