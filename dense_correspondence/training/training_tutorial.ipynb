# %%
import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()
from dense_correspondence.training.training import *
import sys
import logging

# utils.set_default_cuda_visible_devices()
utils.set_cuda_visible_devices([2]) # use this to manually set CUDA_VISIBLE_DEVICES

from dense_correspondence.training.training import DenseCorrespondenceTraining
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
logging.basicConfig(level=logging.INFO)
# Out:
# setting CUDA_VISIBLE_DEVICES =  2,

# %% [markdown]
# ## Load the configuration for training

# %%
config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'dataset', 'composite', 'tier1_oracle_1811_only.yaml')
config = utils.getDictFromYamlFilename(config_filename)

train_config_file = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'training', 'training.yaml')

train_config = utils.getDictFromYamlFilename(train_config_file)
dataset = SpartanDataset(config=config)

logging_dir = "code/data_volume/fabric_data/trained_models/tutorials"
num_iterations = 3500
d = 3 # the descriptor dimension
normalize = True
name = "tier1_oracle_1811_%d" %(d)
train_config["training"]["logging_dir_name"] = name
train_config["training"]["logging_dir"] = logging_dir
train_config["dense_correspondence_network"]["descriptor_dimension"] = d
train_config["dense_correspondence_network"]["normalize"] = normalize
train_config["training"]["num_iterations"] = num_iterations

TRAIN = True
EVALUATE = True
print(config)
# Out:
# scene directory: /home/adi/code/data_volume/fabric_data/logs_proto/tier1_oracle_1811/processed
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     1812
# {'logs_root_path': 'code/data_volume/fabric_data/logs_proto', 'single_object_scenes_config_files': ['tier1_oracle_1811.yaml'], 'multi_object_scenes_config_files': []}

# %% [markdown]
# ## TRAIN

# %%
# All of the saved data for this network will be located in the
# code/data_volume/pdc/trained_models/tutorials/caterpillar_3 folder

if TRAIN:
    print "training descriptor of dimension %d" %(d)
    train = DenseCorrespondenceTraining(dataset=dataset, config=train_config)
    train.run()
    print "finished training descriptor of dimension %d" %(d)
# Out:
# INFO:root:Loading knots info for scene tier1_oracle_1811
# training descriptor of dimension 3
# INFO:root:enabling domain randomization
# INFO:root:setting up tensorboard_logger
# INFO:root:tensorboard logger started
# using SINGLE_OBJECT_WITHIN_SCENE
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:2562: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 1 took 0.153 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 2 took 0.128 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3 took 0.129 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 4 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 5 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 6 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 7 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 8 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 9 took 0.121 seconds
# logging train loss
# Same scene, same object
# INFO:root:Training on iteration 10 of 3500
# INFO:root:single iteration took 0.122 seconds
# INFO:root:Training is 0 percent complete
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 10 took 0.122 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 11 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 12 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 13 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 14 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 15 took 0.122 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 16 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 17 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 18 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 19 took 0.119 seconds
# logging train loss
# Same scene, same object
# INFO:root:Training on iteration 20 of 3500
# INFO:root:single iteration took 0.121 seconds
# INFO:root:Training is 0 percent complete
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 20 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 21 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 22 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 23 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 24 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 25 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 26 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 27 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 28 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 29 took 0.119 seconds
# logging train loss
# Same scene, same object
# INFO:root:Training on iteration 30 of 3500
# INFO:root:single iteration took 0.120 seconds
# INFO:root:Training is 0 percent complete
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 30 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 31 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 32 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 33 took 0.122 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 34 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 35 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 36 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 37 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 38 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 39 took 0.118 seconds
# logging train loss
# Same scene, same object
# INFO:root:Training on iteration 40 of 3500
# INFO:root:single iteration took 0.117 seconds
# INFO:root:Training is 1 percent complete
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 40 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 41 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 42 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 43 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 44 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 45 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 46 took 0.121 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 47 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 48 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 49 took 0.119 seconds
# logging train loss
# Same scene, same object
# INFO:root:Training on iteration 50 of 3500
# INFO:root:single iteration took 0.120 seconds
# INFO:root:Training is 1 percent complete
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 50 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 51 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 52 took 0.120 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 53 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 54 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 55 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 56 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 57 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 58 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 59 took 0.118 seconds
# logging train loss
# Same scene, same object
# INFO:root:Training on iteration 60 of 3500
# INFO:root:single iteration took 0.118 seconds
# INFO:root:Training is 1 percent complete
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3491 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3492 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3493 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3494 took 0.118 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3495 took 0.116 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3496 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3497 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3498 took 0.117 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3499 took 0.119 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3500 took 0.118 seconds
# logging train loss
# INFO:root:Training on iteration 3500 of 3500
# INFO:root:single iteration took 0.118 seconds
# INFO:root:Training is 100 percent complete
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 3501 took 0.117 seconds
# logging train loss
# INFO:root:Finished testing after 3500 iterations
# finished training descriptor of dimension 3

# %% [markdown]
# ## EVAL

# %%
model_folder = os.path.join(logging_dir, name)
model_folder = utils.convert_to_absolute_path(model_folder)

if True: #EVALUATE
    DCE = DenseCorrespondenceEvaluation
    num_image_pairs = 100
    DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs)
# Out:
# got /home/adi/code/data_volume/fabric_data/trained_models/tutorials/tier1_oracle_1811_3
# got output_dir
# got train_output_dir /home/adi/code/data_volume/fabric_data/trained_models/tutorials/tier1_oracle_1811_3/analysis/train
# got test_output_dir /home/adi/code/data_volume/fabric_data/trained_models/tutorials/tier1_oracle_1811_3/analysis/test
# got cross_scene_output_dir /home/adi/code/data_volume/fabric_data/trained_models/tutorials/tier1_oracle_1811_3/analysis/cross_scene
# making necessary dirs
# model_param_file 003501.pth
# INFO:root:Computing descriptor statistics on dataset
# INFO:root:Loading knots info for scene tier1_oracle_1811
# scene directory: /home/adi/code/data_volume/fabric_data/logs_proto/tier1_oracle_1811/processed
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     1812
# computing stats
# doing dcn eval
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# INFO:root:Evaluating network on train data
# normalizing descriptor norm
# done computing stats
# computing statistics for image 0 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 5 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 10 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 15 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 20 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 25 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 30 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 35 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 40 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 45 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 50 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 55 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 60 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 65 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 70 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 75 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 80 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 85 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 90 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# computing statistics for image 95 of 100, scene_name tier1_oracle_1811
# scene
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# normalizing descriptor norm
# INFO:root:Evaluating network on test data
# INFO:root:Loading knots info for scene tier1_oracle_1811_test
# computing statistics for image 0 of 100, scene_name tier1_oracle_1811_test
# scene
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-20b1dbba81a4> in <module>()
#       5     DCE = DenseCorrespondenceEvaluation
#       6     num_image_pairs = 100
# ----> 7     DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs)
#
# /home/adi/code/dense_correspondence/evaluation/evaluation.pyc in run_evaluation_on_network(model_folder, num_image_pairs, num_matches_per_image_pair, save_folder_name, compute_descriptor_statistics, cross_scene, dataset)
#    2037         dataset.set_test_mode()
#    2038         pd_dataframe_list, df = DCE.evaluate_network(dcn, dataset, num_image_pairs=num_image_pairs,
# -> 2039                                                      num_matches_per_image_pair=num_matches_per_image_pair)
#    2040
#    2041         test_csv = os.path.join(test_output_dir, "data.csv")
#
# /home/adi/code/dense_correspondence/evaluation/evaluation.pyc in evaluate_network(dcn, dataset, num_image_pairs, num_matches_per_image_pair)
#     383
#     384
# --> 385             idx_pair = DCE.get_image_pair_random(dataset, scene_name)
#     386
#     387             if idx_pair is None:
#
# /home/adi/code/dense_correspondence/evaluation/evaluation.pyc in get_image_pair_random(dataset, scene_name)
#     216     @staticmethod
#     217     def get_image_pair_random(dataset, scene_name):
# --> 218         img_a_idx = dataset.get_random_image_index(scene_name)
#     219         img_b_idx = dataset.get_random_image_index(scene_name)
#     220         #while img_b_idx == img_a_idx:
#
# /home/adi/code/dense_correspondence/dataset/spartan_dataset_masked.pyc in get_random_image_index(self, scene_name)
#     366         """
#     367         if self._image_index_sample_range is None:
# --> 368             knots_info = self.get_knots_info(scene_name)
#     369             image_idxs = knots_info.keys()
#     370             random_idx = int(random.choice(image_idxs))
#
# /home/adi/code/dense_correspondence/dataset/spartan_dataset_masked.pyc in get_knots_info(self, scene_name)
#     288             logging.info("Loading knots info for scene %s" %(scene_name))
#     289             knots_info_filename = os.path.join(self.get_full_path_for_scene(scene_name), 'images', 'knots_info.json')
# --> 290             self._knots_info[scene_name] = utils.getDictFromJSONFilename(knots_info_filename)
#     291 #            knots_info_filename = os.path.join(self.get_full_path_for_scene(scene_name), 'images', 'knots_info.yaml')
#     292 #            self._knots_info[scene_name] = utils.getDictFromYamlFilename(knots_info_filename)
#
# /home/adi/code/modules/dense_correspondence_manipulation/utils/utils.pyc in getDictFromJSONFilename(filename)
#      16
#      17 def getDictFromJSONFilename(filename):
# ---> 18     with open(filename, "r") as stream:
#      19         return json.load(stream)
#      20
#
# IOError: [Errno 2] No such file or directory: '/home/adi/code/data_volume/fabric_data/logs_proto/tier1_oracle_1811_test/processed/images/knots_info.json'

# %% [markdown]
# See `evaluation_quantitative_tutorial.ipynb` for a better place to display the plots.
