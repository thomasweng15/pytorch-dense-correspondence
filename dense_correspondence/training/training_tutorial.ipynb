# %%
import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()
from dense_correspondence.training.training import *
import sys
import logging

# utils.set_default_cuda_visible_devices()
utils.set_cuda_visible_devices([1, 2, 3, 4, 5, 6, 7]) # use this to manually set CUDA_VISIBLE_DEVICES

from dense_correspondence.training.training import DenseCorrespondenceTraining
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
logging.basicConfig(level=logging.INFO)
# Out:
# setting CUDA_VISIBLE_DEVICES =  1,2,3,4,5,6,7,

# %% [markdown]
# ## Load the configuration for training

# %%
config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'dataset', 'composite', 'rope_nonrigid_412vert_only.yaml')
config = utils.getDictFromYamlFilename(config_filename)

train_config_file = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'training', 'training.yaml')

train_config = utils.getDictFromYamlFilename(train_config_file)
dataset = SpartanDataset(config=config)

logging_dir = "code/data_volume/pdc_synthetic_2/trained_models/tutorials"
num_iterations = 3500
d = 3 # the descriptor dimension
normalize = False
name = "rope_nonrigid_412vert_%d" %(d)
train_config["training"]["logging_dir_name"] = name
train_config["training"]["logging_dir"] = logging_dir
train_config["dense_correspondence_network"]["descriptor_dimension"] = d
train_config["dense_correspondence_network"]["normalize"] = normalize
train_config["training"]["num_iterations"] = num_iterations

TRAIN = True
EVALUATE = True
# Out:
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     3400

# %% [markdown]
# ## TRAIN

# %%
# All of the saved data for this network will be located in the
# code/data_volume/pdc/trained_models/tutorials/caterpillar_3 folder

if TRAIN:
    print "training descriptor of dimension %d" %(d)
    train = DenseCorrespondenceTraining(dataset=dataset, config=train_config)
    train.run()
    print "finished training descriptor of dimension %d" %(d)
# Out:
# INFO:root:Loading knots info for scene rope_nonrigid_412vert
# training descriptor of dimension 3
# INFO:root:enabling domain randomization
# INFO:root:setting up tensorboard_logger
# INFO:root:tensorboard logger started
# using SINGLE_OBJECT_WITHIN_SCENE
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:2622: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.162 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.133 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 10 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 0 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 20 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 0 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 30 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 0 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 40 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 1 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 50 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 1 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 60 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 1 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 70 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 2 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 80 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 2 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 90 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 2 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 100 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 2 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 110 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 3 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# INFO:root:Training on iteration 120 of 3500
# INFO:root:single iteration took 0.123 seconds
# INFO:root:Training is 3 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 130 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 3 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 140 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 4 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 150 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 4 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 160 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 4 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 170 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 4 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 180 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 5 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 190 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 5 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 200 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 5 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 210 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 6 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 220 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 6 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 230 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 6 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 240 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 6 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 250 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 7 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 260 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 7 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 270 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 7 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 280 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 8 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 290 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 8 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 300 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 8 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 310 of 3500
# INFO:root:single iteration took 0.127 seconds
# INFO:root:Training is 8 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.123 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 320 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 9 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 330 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 9 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 340 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 9 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 350 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 10 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 360 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 10 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 370 of 3500
# INFO:root:single iteration took 0.124 seconds
# INFO:root:Training is 10 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 380 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 10 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# INFO:root:Training on iteration 390 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 11 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 400 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 11 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 410 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 11 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# Same scene, same object
# ...
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 3370 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 96 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3380 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 96 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# INFO:root:Training on iteration 3390 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 96 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.124 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# INFO:root:Training on iteration 3400 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 97 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.129 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# INFO:root:Training on iteration 3410 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 97 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3420 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 97 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3430 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 98 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3440 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 98 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# INFO:root:Training on iteration 3450 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 98 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3460 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 98 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3470 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 99 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3480 of 3500
# INFO:root:single iteration took 0.125 seconds
# INFO:root:Training is 99 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# INFO:root:Training on iteration 3490 of 3500
# INFO:root:single iteration took 0.127 seconds
# INFO:root:Training is 99 percent complete
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.127 seconds
# Same scene, same object
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.126 seconds
# INFO:root:Training on iteration 3500 of 3500
# INFO:root:single iteration took 0.126 seconds
# INFO:root:Training is 100 percent complete
# Same scene, same object
# INFO:root:Finished testing after 3500 iterations
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# single iteration took 0.125 seconds
# finished training descriptor of dimension 3

# %% [markdown]
# ## EVAL

# %%
model_folder = os.path.join(logging_dir, name)
model_folder = utils.convert_to_absolute_path(model_folder)

if True: #EVALUATE
    DCE = DenseCorrespondenceEvaluation
    num_image_pairs = 100
    DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs)
# Out:
# got /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_nonrigid_412vert_3
# got output_dir
# got train_output_dir /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_nonrigid_412vert_3/analysis/train
# got test_output_dir /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_nonrigid_412vert_3/analysis/test
# got cross_scene_output_dir /home/priya/code/data_volume/pdc_synthetic_2/trained_models/tutorials/rope_nonrigid_412vert_3/analysis/cross_scene
# making necessary dirs
# model_param_file 003501.pth
# INFO:root:Computing descriptor statistics on dataset
# INFO:root:Loading knots info for scene rope_nonrigid_412vert
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     3400
# computing stats
# doing dcn eval
# INFO:root:Evaluating network on train data
# done computing stats
# computing statistics for image 0 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 5 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 10 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 15 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 20 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 25 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 30 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 35 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 40 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 45 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 50 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 55 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 60 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 65 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 70 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 75 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 80 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 85 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 90 of 100, scene_name rope_nonrigid_412vert
# scene
# computing statistics for image 95 of 100, scene_name rope_nonrigid_412vert
# scene
# INFO:root:Evaluating network on test data
# INFO:root:Loading knots info for scene rope_nonrigid_412vert_test
# computing statistics for image 0 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 5 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 10 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 15 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 20 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 25 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 30 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 35 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 40 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 45 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 50 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 55 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 60 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 65 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 70 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 75 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 80 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 85 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 90 of 100, scene_name rope_nonrigid_412vert_test
# scene
# computing statistics for image 95 of 100, scene_name rope_nonrigid_412vert_test
# scene
# INFO:root:Making plots
# INFO:root:Finished running evaluation on network

# %% [markdown]
# See `evaluation_quantitative_tutorial.ipynb` for a better place to display the plots.
