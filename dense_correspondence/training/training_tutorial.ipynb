# %%
import dense_correspondence_manipulation.utils.utils as utils
utils.add_dense_correspondence_to_python_path()
from dense_correspondence.training.training import *
import sys
import logging

# utils.set_default_cuda_visible_devices()
utils.set_cuda_visible_devices([0]) # use this to manually set CUDA_VISIBLE_DEVICES

from dense_correspondence.training.training import DenseCorrespondenceTraining
from dense_correspondence.dataset.spartan_dataset_masked import SpartanDataset
from dense_correspondence.evaluation.evaluation import DenseCorrespondenceEvaluation
logging.basicConfig(level=logging.INFO)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-084ef6b3d66a> in <module>()
# ----> 1 import dense_correspondence_manipulation.utils.utils as utils
#       2 utils.add_dense_correspondence_to_python_path()
#       3 from dense_correspondence.training.training import *
#       4 import sys
#       5 import logging
#
# ImportError: No module named dense_correspondence_manipulation.utils.utils

# %% [markdown]
# ## Load the configuration for training

# %%
config_filename = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'dataset', 'composite', 'rope_noisy_1400_only.yaml')
config = utils.getDictFromYamlFilename(config_filename)

train_config_file = os.path.join(utils.getDenseCorrespondenceSourceDir(), 'config', 'dense_correspondence', 
                               'training', 'training.yaml')

train_config = utils.getDictFromYamlFilename(train_config_file)
dataset = SpartanDataset(config=config)

logging_dir = "code/data_volume/pdc_synthetic_2/trained_models/tutorials"
num_iterations = 3500
d = 3 # the descriptor dimension
normalize = True
name = "TEST_%d" %(d)
train_config["training"]["logging_dir_name"] = name
train_config["training"]["logging_dir"] = logging_dir
train_config["dense_correspondence_network"]["descriptor_dimension"] = d
train_config["dense_correspondence_network"]["normalize"] = normalize
train_config["training"]["num_iterations"] = num_iterations

TRAIN = True
EVALUATE = True
# Out:
# Using SpartanDataset:
#    - in train mode
#    - number of scenes 1
#    - total images:     3600

# %% [markdown]
# ## TRAIN

# %%
# All of the saved data for this network will be located in the
# code/data_volume/pdc/trained_models/tutorials/caterpillar_3 folder

if TRAIN:
    print "training descriptor of dimension %d" %(d)
    train = DenseCorrespondenceTraining(dataset=dataset, config=train_config)
    train.run()
    print "finished training descriptor of dimension %d" %(d)
# Out:
# training descriptor of dimension 3
# using SINGLE_OBJECT_WITHIN_SCENE
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# Same scene, same object
# /usr/local/lib/python2.7/dist-packages/torch/nn/functional.py:2622: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 1 took 0.172 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 2 took 0.133 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 68 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 69 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 70 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 71 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 72 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 73 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 74 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 75 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 76 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 77 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 78 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 79 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 80 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 81 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 82 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 83 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 84 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 85 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 86 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 87 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 88 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 89 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 90 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 91 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 92 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 93 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 94 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 95 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 96 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 97 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 98 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 99 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 100 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 101 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 102 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 103 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 104 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 105 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 106 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 107 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 108 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 109 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 110 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 111 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 112 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 113 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 114 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 115 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 116 took 0.125 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 117 took 0.123 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 118 took 0.124 seconds
# logging train loss
# Same scene, same object
# normalizing descriptor norm
# normalizing descriptor norm
# applying SINGLE_OBJECT_WITHIN_SCENE loss
# iteration 119 took 0.124 seconds
# logging train loss
# Same scene, same object

# %% [markdown]
# ## EVAL

# %%
model_folder = os.path.join(logging_dir, name)
model_folder = utils.convert_to_absolute_path(model_folder)

if True: #EVALUATE
    DCE = DenseCorrespondenceEvaluation
    num_image_pairs = 100
    DCE.run_evaluation_on_network(model_folder, num_image_pairs=num_image_pairs)

# %% [markdown]
# See `evaluation_quantitative_tutorial.ipynb` for a better place to display the plots.
